# %% [markdown]
# ## Librerías y rutas

# %%
import os
import pandas as pd

# %%
path = './Estaciones'

# %% [markdown]
# ## Función para leer los datos de la estación, regresa un diccionario

# %%
def leer_smn_encabezado( archivo ):
    
    with open( archivo, 'rb' ) as f:
   
        next( f ).decode('latin-1')
        next( f ).decode('latin-1')
        next( f ).decode('latin-1')
        next( f ).decode('latin-1')
   
        est_numero = next( f ).decode('latin-1')
        est_numero = int( est_numero.split(':')[1] )
        est_nombre = next( f ).decode('latin-1')
        est_nombre = est_nombre.split(':')[1].strip()
        est_estado = next( f ).decode('latin-1')
        est_estado = est_estado.split(':')[1].strip()
        est_municipio = next( f ).decode('latin-1')
        est_municipio = est_municipio.split(':')[1].strip()
        est_situacion = next( f ).decode('latin-1')
        est_organismo = next( f ).decode('latin-1')
        est_cve = next( f ).decode('latin-1')
        est_latitud = next( f ).decode('latin-1')
        est_latitud = est_latitud.split(':')[1].strip()
        est_latitud = est_latitud.split('°')[0]       #elimina "°"
        est_longitud = next( f ).decode('latin-1')
        est_longitud = est_longitud.split(':')[1].strip()
        est_longitud = est_longitud.split('°')[0]     #elimina "°"
        est_altitud = next( f ).decode('latin-1')
        est_altitud = est_altitud.split(':')[1].strip()
        est_altitud = est_altitud.split(' ')[0].replace(',','')       #elimina " msnm"
   
        print( est_numero, est_nombre, est_estado, est_municipio )
        print( est_latitud, est_longitud, est_altitud )
        
#        fest.write(str(est_numero)+", "+ est_latitud+", "+ est_longitud+ ", "+ est_altitud+"\n")
#        fest.write(str(est_numero)+", "+ est_latitud+", "+ est_longitud +"\n")
    
        encabezado = { 'numero': est_numero,
                       'nombre': est_nombre,
                       'estado': est_estado,
                       'municipio': est_municipio,
                       'situacion': est_situacion,
                       'organismo': est_organismo,
                       'cve': est_cve,
                       'latitud': est_latitud,
                       'longitud': est_longitud,
                       'altitud': est_altitud }
        return encabezado

# %% [markdown]
# ## Extraer las coordenadas de todos los archivos y guardarlas en "estaciones.csv"

# %%
fest = open(path+"/estaciones.csv",'w')
fest.write("Numero, Latitud, Longitud, Altitud\n")
# Out:
# 26

# %%
files = os.listdir(path)

for ff in files:
    if ff.endswith(".txt"):
        archivo = os.path.join( path, ff )
        enc = leer_smn_encabezado( archivo )
        fest.write(str(enc['numero'])+", "+ enc['latitud']+", "+ enc['longitud']+ ", "+ enc['altitud']+"\n")

fest.close()

print("terminado el proceso")
# Out:
# 7175 VILLAFLORES (SMN) CHIAPAS VILLAFLORES
# 016.229 -093.263 554
# 13022 PACHUCA (OBS) HIDALGO PACHUCA DE SOTO
# 020.088 -098.750 2369
# 14006 AJOJUCAR JALISCO TEOCALTICHE
# 021.563 -102.439 1745
# 32038 NIEVES ZACATECAS GENERAL FRANCISCO R. MURGUIA
# 024.001 -103.019 1913
# 14142 TAPALPA (SMN) JALISCO TAPALPA
# 019.945 -103.758 2060
# 5026 PRESA COYOTE COAHUILA DE ZARAGOZA TORREON
# 025.542 -103.469 1223
# 14068 HOSTOTIPAQUILLO JALISCO HOSTOTIPAQUILLO
# terminado el proceso

# %% [markdown]
# ## Función para leer los datos, regresa un data frame

# %%
def leer_smn_mediciones(archivo):
    
    est_numero = archivo.split('.')[1].split('/')[2]
    
    archivosalida=archivo.split('.')[0]+".csv"
 
    print("archivo de entrada: "+archivo)
    print("archivo de salida: "+archivosalida)
       
    df = pd.read_fwf( archivo, skiprows=18 )
   
    df.columns = [ 'Fecha', 'Precipitacion', 'Evaporacion', 'T_max', 'T_min' ]
    print( 'Dataframe original... ', df.shape )

    #    df = df[ df['Precipitacion'].str[0]!='-' ] # sí funciona
    #    df = df[ df['Precipitacion'].apply( lambda x: '-' not in x) ] # sí funciona
    mask = df['Precipitacion'].str.contains( r'-' )
    df = df[ ~mask ]
    print( 'Revisado - en precipitacion... ', df.shape )

    mask = df['Fecha'].str.contains( r'\d\d/\d\d/\d\d\d\d', na=False )
    df = df[ mask ]
    print( 'Revisada la fecha... ', df.shape )
   
    df['Precipitacion'] = df['Precipitacion'].apply(pd.to_numeric, errors='coerce')
    df['Evaporacion'] = df['Evaporacion'].apply(pd.to_numeric, errors='coerce')
    df['T_max'] = df['T_max'].apply(pd.to_numeric, errors='coerce')
    df['T_min'] = df['T_min'].apply(pd.to_numeric, errors='coerce')
   

    #Versión para buscar errores
    # try:    
    #     df['Dia'] = df['Fecha'].apply( lambda x: x.split('/')[0] )
    #     df['Mes'] = df['Fecha'].apply( lambda x: x.split('/')[1] )
    #     df['Anyo'] = df['Fecha'].apply( lambda x: x.split('/')[2] )
    # except Exception as e:
    #     print( e.__class__ )
    #     for index, row in df.iterrows():
    #         fecha = row['Fecha']
    #         try:
    #             dma = row['Fecha'].split('/')
    #             if len( dma )<3:
    #                 print( dma )
    #         except Exception as e:
    #             print( dma, type(dma) )                
    #             print( e.__class__ )
    #             return 0

    df['Dia'] = df['Fecha'].apply( lambda x: x.split('/')[0] )
    df['Mes'] = df['Fecha'].apply( lambda x: x.split('/')[1] )
    df['Anyo'] = df['Fecha'].apply( lambda x: x.split('/')[2] )

    df['Estacion'] = est_numero
    df = df[ [ 'Estacion', 'Dia', 'Mes', 'Anyo', 'Precipitacion', 'Evaporacion', 'T_max', 'T_min' ] ]
    
    return df
           
#    df.to_csv( archivosalida, sep=',', index=None, na_rep=-99999 )

# %% [markdown]
# ## Se leen todos los archivos, pero solo los datos, y se concatenan en un solo archivo grande

# %%
files = os.listdir(path)
files = [ os.path.join( path, ff ) for ff in files if 'txt' in ff]

# %%
df_grande = pd.concat( [ leer_smn_mediciones(ff) for ff in files ] )

print( df_grande.shape )

print("terminado el proceso")
# Out:
# archivo de entrada: ./Estaciones/7175.txt
# archivo de salida: .csv
# Dataframe original...  (30104, 5)
# Revisado - en precipitacion...  (30103, 5)
# Revisada la fecha...  (30103, 5)
# archivo de entrada: ./Estaciones/13022.txt
# archivo de salida: .csv
# Dataframe original...  (26793, 5)
# Revisado - en precipitacion...  (26792, 5)
# Revisada la fecha...  (26792, 5)
# archivo de entrada: ./Estaciones/14006.txt
# archivo de salida: .csv
# Dataframe original...  (28020, 5)
# Revisado - en precipitacion...  (28019, 5)
# Revisada la fecha...  (28019, 5)
# archivo de entrada: ./Estaciones/32038.txt
# archivo de salida: .csv
# Dataframe original...  (27244, 5)
# Revisado - en precipitacion...  (27243, 5)
# Revisada la fecha...  (27243, 5)
# archivo de entrada: ./Estaciones/14142.txt
# archivo de salida: .csv
# Dataframe original...  (27528, 5)
# Revisado - en precipitacion...  (27527, 5)
# Revisada la fecha...  (27527, 5)
# archivo de entrada: ./Estaciones/5026.txt
# archivo de salida: .csv
# Dataframe original...  (27259, 5)
# Revisado - en precipitacion...  (27258, 5)
# Revisada la fecha...  (27258, 5)
# archivo de entrada: ./Estaciones/14068.txt
# archivo de salida: .csv
# Dataframe original...  (27305, 5)
# Revisado - en precipitacion...  (27304, 5)
# Revisada la fecha...  (27304, 5)
# archivo de entrada: ./Estaciones/3062.txt
# archivo de salida: .csv
# Dataframe original...  (28666, 5)
# Revisado - en precipitacion...  (28665, 5)
# Revisada la fecha...  (28665, 5)
# archivo de entrada: ./Estaciones/3038.txt
# archivo de salida: .csv
# Dataframe original...  (32257, 5)
# Revisado - en precipitacion...  (32256, 5)
# Revisada la fecha...  (32256, 5)
# archivo de entrada: ./Estaciones/8099.txt
# archivo de salida: .csv
# Dataframe original...  (31525, 5)
# Revisado - en precipitacion...  (31524, 5)
# Revisada la fecha...  (31524, 5)
# archivo de entrada: ./Estaciones/12002.txt
# archivo de salida: .csv
# Dataframe original...  (29042, 5)
# Revisado - en precipitacion...  (29041, 5)
# Revisada la fecha...  (29041, 5)
# archivo de entrada: ./Estaciones/14030.txt
# archivo de salida: .csv
# Dataframe original...  (30407, 5)
# Revisado - en precipitacion...  (30406, 5)
# Revisada la fecha...  (30404, 5)
# archivo de entrada: ./Estaciones/14141.txt
# archivo de salida: .csv
# Dataframe original...  (29659, 5)
# Revisado - en precipitacion...  (29658, 5)
# Revisada la fecha...  (29658, 5)
# archivo de entrada: ./Estaciones/11079.txt
# archivo de salida: .csv
# Dataframe original...  (30395, 5)
# Revisado - en precipitacion...  (30394, 5)
# Revisada la fecha...  (30394, 5)
# archivo de entrada: ./Estaciones/32054.txt
# archivo de salida: .csv
# Dataframe original...  (28404, 5)
# Revisado - en precipitacion...  (28403, 5)
# Revisada la fecha...  (28403, 5)
# archivo de entrada: ./Estaciones/19048.txt
# archivo de salida: .csv
# Dataframe original...  (27948, 5)
# Revisado - en precipitacion...  (27947, 5)
# Revisada la fecha...  (27947, 5)
# archivo de entrada: ./Estaciones/14009.txt
# archivo de salida: .csv
# Dataframe original...  (28386, 5)
# Revisado - en precipitacion...  (28385, 5)
# Revisada la fecha...  (28385, 5)
# archivo de entrada: ./Estaciones/1017.txt
# archivo de salida: .csv
# Dataframe original...  (27766, 5)
# Revisado - en precipitacion...  (27765, 5)
# Revisada la fecha...  (27765, 5)
# archivo de entrada: ./Estaciones/8270.txt
# archivo de salida: .csv
# Dataframe original...  (31962, 5)
# Revisado - en precipitacion...  (31961, 5)
# Revisada la fecha...  (31961, 5)
# archivo de entrada: ./Estaciones/17028.txt
# archivo de salida: .csv
# Dataframe original...  (26696, 5)
# Revisado - en precipitacion...  (26695, 5)
# Revisada la fecha...  (26695, 5)
# archivo de entrada: ./Estaciones/16109.txt
# archivo de salida: .csv
# Dataframe original...  (33635, 5)
# Revisado - en precipitacion...  (33634, 5)
# Revisada la fecha...  (33634, 5)
# archivo de entrada: ./Estaciones/26053.txt
# archivo de salida: .csv
# Dataframe original...  (31656, 5)
# Revisado - en precipitacion...  (31655, 5)
# Revisada la fecha...  (31655, 5)
# archivo de entrada: ./Estaciones/3016.txt
# archivo de salida: .csv
# Dataframe original...  (27167, 5)
# Revisado - en precipitacion...  (27166, 5)
# Revisada la fecha...  (27166, 5)
# archivo de entrada: ./Estaciones/3066.txt
# archivo de salida: .csv
# Dataframe original...  (27388, 5)
# Revisado - en precipitacion...  (27387, 5)
# Revisada la fecha...  (27387, 5)
# archivo de entrada: ./Estaciones/14040.txt
# archivo de salida: .csv
# Dataframe original...  (30614, 5)
# Revisado - en precipitacion...  (30613, 5)
# Revisada la fecha...  (30613, 5)
# archivo de entrada: ./Estaciones/3056.txt
# archivo de salida: .csv
# Dataframe original...  (28703, 5)
# Revisado - en precipitacion...  (28702, 5)
# Revisada la fecha...  (28702, 5)
# archivo de entrada: ./Estaciones/13013.txt
# archivo de salida: .csv
# Dataframe original...  (34837, 5)
# Revisado - en precipitacion...  (34836, 5)
# Revisada la fecha...  (34836, 5)
# archivo de entrada: ./Estaciones/30211.txt
# archivo de salida: .csv
# Dataframe original...  (33349, 5)
# Revisado - en precipitacion...  (33348, 5)
# Revisada la fecha...  (33348, 5)
# archivo de entrada: ./Estaciones/2038.txt
# archivo de salida: .csv
# Dataframe original...  (28869, 5)
# Revisado - en precipitacion...  (28868, 5)
# Revisada la fecha...  (28868, 5)
# archivo de entrada: ./Estaciones/16007.txt
# archivo de salida: .csv
# Dataframe original...  (34329, 5)
# Revisado - en precipitacion...  (34328, 5)
# Revisada la fecha...  (34328, 5)
# archivo de entrada: ./Estaciones/6002.txt
# archivo de salida: .csv
# Dataframe original...  (27947, 5)
# Revisado - en precipitacion...  (27946, 5)
# Revisada la fecha...  (27946, 5)
# archivo de entrada: ./Estaciones/19028.txt
# archivo de salida: .csv
# Dataframe original...  (28193, 5)
# Revisado - en precipitacion...  (28192, 5)
# Revisada la fecha...  (28192, 5)
# archivo de entrada: ./Estaciones/10068.txt
# archivo de salida: .csv
# Dataframe original...  (27768, 5)
# Revisado - en precipitacion...  (27767, 5)
# Revisada la fecha...  (27767, 5)
# archivo de entrada: ./Estaciones/10100.txt
# archivo de salida: .csv
# Dataframe original...  (33603, 5)
# Revisado - en precipitacion...  (33602, 5)
# Revisada la fecha...  (33602, 5)
# archivo de entrada: ./Estaciones/30163.txt
# archivo de salida: .csv
# Dataframe original...  (28617, 5)
# Revisado - en precipitacion...  (28616, 5)
# Revisada la fecha...  (28616, 5)
# archivo de entrada: ./Estaciones/11052.txt
# archivo de salida: .csv
# Dataframe original...  (29299, 5)
# Revisado - en precipitacion...  (29298, 5)
# Revisada la fecha...  (29298, 5)
# archivo de entrada: ./Estaciones/3051.txt
# archivo de salida: .csv
# Dataframe original...  (27865, 5)
# Revisado - en precipitacion...  (27864, 5)
# Revisada la fecha...  (27864, 5)
# archivo de entrada: ./Estaciones/16055.txt
# archivo de salida: .csv
# Dataframe original...  (28824, 5)
# Revisado - en precipitacion...  (28823, 5)
# Revisada la fecha...  (28823, 5)
# archivo de entrada: ./Estaciones/20048.txt
# archivo de salida: .csv
# Dataframe original...  (28630, 5)
# Revisado - en precipitacion...  (28629, 5)
# Revisada la fecha...  (28629, 5)
# archivo de entrada: ./Estaciones/8194.txt
# archivo de salida: .csv
# Dataframe original...  (31224, 5)
# Revisado - en precipitacion...  (31223, 5)
# Revisada la fecha...  (31223, 5)
# archivo de entrada: ./Estaciones/16024.txt
# archivo de salida: .csv
# Dataframe original...  (28449, 5)
# Revisado - en precipitacion...  (28448, 5)
# Revisada la fecha...  (28448, 5)
# archivo de entrada: ./Estaciones/18002.txt
# archivo de salida: .csv
# Dataframe original...  (32246, 5)
# Revisado - en precipitacion...  (32245, 5)
# Revisada la fecha...  (32245, 5)
# archivo de entrada: ./Estaciones/19016.txt
# archivo de salida: .csv
# Dataframe original...  (27200, 5)
# Revisado - en precipitacion...  (27199, 5)
# Revisada la fecha...  (27199, 5)
# archivo de entrada: ./Estaciones/3061.txt
# archivo de salida: .csv
# Dataframe original...  (29805, 5)
# Revisado - en precipitacion...  (29804, 5)
# Revisada la fecha...  (29804, 5)
# archivo de entrada: ./Estaciones/16145.txt
# archivo de salida: .csv
# Dataframe original...  (30703, 5)
# Revisado - en precipitacion...  (30702, 5)
# Revisada la fecha...  (30702, 5)
# archivo de entrada: ./Estaciones/30012.txt
# archivo de salida: .csv
# Dataframe original...  (31671, 5)
# Revisado - en precipitacion...  (31670, 5)
# Revisada la fecha...  (31670, 5)
# archivo de entrada: ./Estaciones/11060.txt
# archivo de salida: .csv
# Dataframe original...  (27322, 5)
# Revisado - en precipitacion...  (27321, 5)
# Revisada la fecha...  (27321, 5)
# archivo de entrada: ./Estaciones/17001.txt
# archivo de salida: .csv
# Dataframe original...  (31833, 5)
# Revisado - en precipitacion...  (31832, 5)
# Revisada la fecha...  (31832, 5)
# archivo de entrada: ./Estaciones/11096.txt
# archivo de salida: .csv
# Dataframe original...  (27153, 5)
# Revisado - en precipitacion...  (27152, 5)
# Revisada la fecha...  (27152, 5)
# archivo de entrada: ./Estaciones/13012.txt
# archivo de salida: .csv
# Dataframe original...  (38064, 5)
# Revisado - en precipitacion...  (38063, 5)
# Revisada la fecha...  (38063, 5)
# archivo de entrada: ./Estaciones/13042.txt
# archivo de salida: .csv
# Dataframe original...  (27986, 5)
# Revisado - en precipitacion...  (27985, 5)
# Revisada la fecha...  (27985, 5)
# archivo de entrada: ./Estaciones/16051.txt
# archivo de salida: .csv
# Dataframe original...  (27249, 5)
# Revisado - en precipitacion...  (27248, 5)
# Revisada la fecha...  (27248, 5)
# archivo de entrada: ./Estaciones/3008.txt
# archivo de salida: .csv
# Dataframe original...  (29088, 5)
# Revisado - en precipitacion...  (29087, 5)
# Revisada la fecha...  (29087, 5)
# archivo de entrada: ./Estaciones/20070.txt
# archivo de salida: .csv
# Dataframe original...  (33783, 5)
# Revisado - en precipitacion...  (33782, 5)
# Revisada la fecha...  (33782, 5)
# archivo de entrada: ./Estaciones/30066.txt
# archivo de salida: .csv
# Dataframe original...  (29558, 5)
# Revisado - en precipitacion...  (29557, 5)
# Revisada la fecha...  (29557, 5)
# archivo de entrada: ./Estaciones/8052.txt
# archivo de salida: .csv
# Dataframe original...  (31270, 5)
# Revisado - en precipitacion...  (31269, 5)
# Revisada la fecha...  (31269, 5)
# archivo de entrada: ./Estaciones/26075.txt
# archivo de salida: .csv
# Dataframe original...  (31929, 5)
# Revisado - en precipitacion...  (31928, 5)
# Revisada la fecha...  (31928, 5)
# archivo de entrada: ./Estaciones/12052.txt
# archivo de salida: .csv
# Dataframe original...  (27553, 5)
# Revisado - en precipitacion...  (27552, 5)
# Revisada la fecha...  (27552, 5)
# archivo de entrada: ./Estaciones/14096.txt
# archivo de salida: .csv
# Dataframe original...  (33146, 5)
# Revisado - en precipitacion...  (33145, 5)
# Revisada la fecha...  (33145, 5)
# archivo de entrada: ./Estaciones/21091.txt
# archivo de salida: .csv
# Dataframe original...  (32576, 5)
# Revisado - en precipitacion...  (32575, 5)
# Revisada la fecha...  (32575, 5)
# archivo de entrada: ./Estaciones/19024.txt
# archivo de salida: .csv
# Dataframe original...  (29226, 5)
# Revisado - en precipitacion...  (29225, 5)
# Revisada la fecha...  (29225, 5)
# archivo de entrada: ./Estaciones/21118.txt
# archivo de salida: .csv
# Dataframe original...  (30361, 5)
# Revisado - en precipitacion...  (30360, 5)
# Revisada la fecha...  (30360, 5)
# archivo de entrada: ./Estaciones/8182.txt
# archivo de salida: .csv
# Dataframe original...  (31776, 5)
# Revisado - en precipitacion...  (31775, 5)
# Revisada la fecha...  (31775, 5)
# archivo de entrada: ./Estaciones/8219.txt
# archivo de salida: .csv
# Dataframe original...  (31926, 5)
# Revisado - en precipitacion...  (31925, 5)
# Revisada la fecha...  (31925, 5)
# archivo de entrada: ./Estaciones/11028.txt
# archivo de salida: .csv
# Dataframe original...  (38495, 5)
# Revisado - en precipitacion...  (38494, 5)
# Revisada la fecha...  (38494, 5)
# archivo de entrada: ./Estaciones/11050.txt
# archivo de salida: .csv
# Dataframe original...  (32801, 5)
# Revisado - en precipitacion...  (32800, 5)
# Revisada la fecha...  (32800, 5)
# archivo de entrada: ./Estaciones/16123.txt
# archivo de salida: .csv
# Dataframe original...  (31407, 5)
# Revisado - en precipitacion...  (31406, 5)
# Revisada la fecha...  (31406, 5)
# archivo de entrada: ./Estaciones/2072.txt
# archivo de salida: .csv
# Dataframe original...  (28328, 5)
# Revisado - en precipitacion...  (28327, 5)
# Revisada la fecha...  (28327, 5)
# archivo de entrada: ./Estaciones/11002.txt
# archivo de salida: .csv
# Dataframe original...  (28810, 5)
# Revisado - en precipitacion...  (28809, 5)
# Revisada la fecha...  (28809, 5)
# archivo de entrada: ./Estaciones/11064.txt
# archivo de salida: .csv
# Dataframe original...  (29062, 5)
# Revisado - en precipitacion...  (29061, 5)
# Revisada la fecha...  (29061, 5)
# archivo de entrada: ./Estaciones/7119.txt
# archivo de salida: .csv
# Dataframe original...  (32565, 5)
# Revisado - en precipitacion...  (32564, 5)
# Revisada la fecha...  (32564, 5)
# archivo de entrada: ./Estaciones/17029.txt
# archivo de salida: .csv
# Dataframe original...  (26696, 5)
# Revisado - en precipitacion...  (26695, 5)
# Revisada la fecha...  (26695, 5)
# archivo de entrada: ./Estaciones/16065.txt
# archivo de salida: .csv
# Dataframe original...  (28568, 5)
# Revisado - en precipitacion...  (28567, 5)
# Revisada la fecha...  (28567, 5)
# archivo de entrada: ./Estaciones/8215.txt
# archivo de salida: .csv
# Dataframe original...  (31240, 5)
# Revisado - en precipitacion...  (31239, 5)
# Revisada la fecha...  (31239, 5)
# archivo de entrada: ./Estaciones/11024.txt
# archivo de salida: .csv
# Dataframe original...  (29839, 5)
# Revisado - en precipitacion...  (29838, 5)
# Revisada la fecha...  (29836, 5)
# archivo de entrada: ./Estaciones/3074.txt
# archivo de salida: .csv
# Dataframe original...  (27176, 5)
# Revisado - en precipitacion...  (27175, 5)
# Revisada la fecha...  (27175, 5)
# archivo de entrada: ./Estaciones/25046.txt
# archivo de salida: .csv
# Dataframe original...  (26981, 5)
# Revisado - en precipitacion...  (26980, 5)
# Revisada la fecha...  (26980, 5)
# archivo de entrada: ./Estaciones/1019.txt
# archivo de salida: .csv
# Dataframe original...  (27930, 5)
# Revisado - en precipitacion...  (27929, 5)
# Revisada la fecha...  (27929, 5)
# archivo de entrada: ./Estaciones/30108.txt
# archivo de salida: .csv
# Dataframe original...  (27944, 5)
# Revisado - en precipitacion...  (27943, 5)
# Revisada la fecha...  (27943, 5)
# archivo de entrada: ./Estaciones/12047.txt
# archivo de salida: .csv
# Dataframe original...  (29521, 5)
# Revisado - en precipitacion...  (29520, 5)
# Revisada la fecha...  (29520, 5)
# archivo de entrada: ./Estaciones/9048.txt
# archivo de salida: .csv
# Dataframe original...  (51483, 5)
# Revisado - en precipitacion...  (51482, 5)
# Revisada la fecha...  (51480, 5)
# archivo de entrada: ./Estaciones/1018.txt
# archivo de salida: .csv
# Dataframe original...  (31107, 5)
# Revisado - en precipitacion...  (31106, 5)
# Revisada la fecha...  (31106, 5)
# archivo de entrada: ./Estaciones/11009.txt
# archivo de salida: .csv
# Dataframe original...  (34333, 5)
# Revisado - en precipitacion...  (34332, 5)
# Revisada la fecha...  (34332, 5)
# archivo de entrada: ./Estaciones/10029.txt
# archivo de salida: .csv
# Dataframe original...  (30749, 5)
# Revisado - en precipitacion...  (30748, 5)
# Revisada la fecha...  (30748, 5)
# archivo de entrada: ./Estaciones/3029.txt
# archivo de salida: .csv
# Dataframe original...  (28708, 5)
# Revisado - en precipitacion...  (28707, 5)
# Revisada la fecha...  (28707, 5)
# archivo de entrada: ./Estaciones/11068.txt
# archivo de salida: .csv
# Dataframe original...  (28462, 5)
# Revisado - en precipitacion...  (28461, 5)
# Revisada la fecha...  (28461, 5)
# archivo de entrada: ./Estaciones/3060.txt
# archivo de salida: .csv
# Dataframe original...  (27819, 5)
# Revisado - en precipitacion...  (27818, 5)
# Revisada la fecha...  (27818, 5)
# archivo de entrada: ./Estaciones/11036.txt
# archivo de salida: .csv
# Dataframe original...  (27570, 5)
# Revisado - en precipitacion...  (27569, 5)
# Revisada la fecha...  (27569, 5)
# archivo de entrada: ./Estaciones/14066.txt
# archivo de salida: .csv
# Dataframe original...  (29859, 5)
# Revisado - en precipitacion...  (29858, 5)
# Revisada la fecha...  (29858, 5)
# archivo de entrada: ./Estaciones/28086.txt
# archivo de salida: .csv
# Dataframe original...  (27944, 5)
# Revisado - en precipitacion...  (27943, 5)
# Revisada la fecha...  (27943, 5)
# archivo de entrada: ./Estaciones/16027.txt
# archivo de salida: .csv
# Dataframe original...  (31266, 5)
# Revisado - en precipitacion...  (31265, 5)
# Revisada la fecha...  (31265, 5)
# archivo de entrada: ./Estaciones/21063.txt
# archivo de salida: .csv
# Dataframe original...  (33237, 5)
# Revisado - en precipitacion...  (33236, 5)
# Revisada la fecha...  (33236, 5)
# archivo de entrada: ./Estaciones/3050.txt
# archivo de salida: .csv
# Dataframe original...  (27440, 5)
# Revisado - en precipitacion...  (27439, 5)
# Revisada la fecha...  (27439, 5)
# archivo de entrada: ./Estaciones/16141.txt
# archivo de salida: .csv
# Dataframe original...  (32302, 5)
# Revisado - en precipitacion...  (32301, 5)
# Revisada la fecha...  (32301, 5)
# archivo de entrada: ./Estaciones/14084.txt
# archivo de salida: .csv
# Dataframe original...  (27490, 5)
# Revisado - en precipitacion...  (27489, 5)
# Revisada la fecha...  (27489, 5)
# archivo de entrada: ./Estaciones/8246.txt
# archivo de salida: .csv
# Dataframe original...  (30449, 5)
# Revisado - en precipitacion...  (30448, 5)
# Revisada la fecha...  (30448, 5)
# archivo de entrada: ./Estaciones/16124.txt
# archivo de salida: .csv
# Dataframe original...  (27093, 5)
# Revisado - en precipitacion...  (27092, 5)
# Revisada la fecha...  (27092, 5)
# archivo de entrada: ./Estaciones/30125.txt
# archivo de salida: .csv
# Dataframe original...  (27131, 5)
# Revisado - en precipitacion...  (27130, 5)
# Revisada la fecha...  (27130, 5)
# archivo de entrada: ./Estaciones/3035.txt
# archivo de salida: .csv
# Dataframe original...  (27682, 5)
# Revisado - en precipitacion...  (27681, 5)
# Revisada la fecha...  (27681, 5)
# archivo de entrada: ./Estaciones/3012.txt
# archivo de salida: .csv
# Dataframe original...  (27978, 5)
# Revisado - en precipitacion...  (27977, 5)
# Revisada la fecha...  (27977, 5)
# (2999115, 8)
# terminado el proceso

# %%
df_grande.to_csv( os.path.join( path, 'smn_mediciones.csv' ), index=False )

# %%
df_grande.to_parquet( os.path.join( path, 'smn_mediciones.parquet' ), index=False )
